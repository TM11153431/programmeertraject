# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 200)

# %%
columns = ['id','scrape_id', 'neighbourhood', 'zipcode', 'property_type', 'room_type', 'accommodates', 'bedrooms', 'beds', 'price', 'number_of_reviews', 'review_scores_rating', 'reviews_per_month'] 
listings = pd.read_csv('listings.csv')
listings = listings[columns]
listings.index = listings['id']
del listings['id']
listings['price'] = listings['price'].replace(['[\$]', '[\,]'], '', regex=True).apply(pd.to_numeric)

# %%
listings
# Out:
#                scrape_id neighbourhood  zipcode    property_type  \
# id
# 14831696  20170402075052           NaN     1054        Apartment
# 3951251   20170402075052           NaN   1057GV        Apartment
# 16590973  20170402075052           NaN   1054XH        Apartment
# 9283701   20170402075052      Oud-West  1057 XD        Apartment
# 6458721   20170402075052      Oud-West  1053 NE        Apartment
# 14864447  20170402075052      Oud-West  1054 JG        Apartment
# 16306240  20170402075052      Oud-West  1053 SP            House
# 15211538  20170402075052           NaN     1056        Apartment
# 1261425   20170402075052      Oud-West     1056  Bed & Breakfast
# 5978154   20170402075052           NaN  1053 WP        Apartment
# 10691231  20170402075052      Oud-West     1056        Apartment
# 8024854   20170402075052      Oud-West     1053        Apartment
# 6606330   20170402075052           NaN     1054        Apartment
# ...

# %%
listings['neighbourhood'].astype('category')
price_reviews = pd.pivot_table(listings, index=['neighbourhood'], values=['price', 'scrape_id','number_of_reviews', 'review_scores_rating', 'reviews_per_month'], aggfunc={'price': np.mean, 'scrape_id': len, 'review_scores_rating': np.mean, 'reviews_per_month': np.mean, 'number_of_reviews': np.sum})

# %%
pd.pivot_table(listings, index='neighbourhood', columns='property_type', values='scrape_id', aggfunc=len)
# Out:
# property_type
# Apartment             7738.0
# Bed & Breakfast        367.0
# Boat                   236.0
# Boutique hotel           6.0
# Bungalow                 2.0
# Cabin                   15.0
# Camper/RV               14.0
# Chalet                   3.0
# Condominium            208.0
# Dorm                     2.0
# Guesthouse               3.0
# House                 1065.0
# Hut                      1.0
# Loft                    81.0
# Other                   48.0
# Serviced apartment       6.0
# Townhouse              121.0
# Villa                   16.0
# dtype: float64
